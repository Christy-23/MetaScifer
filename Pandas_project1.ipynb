# %%
#Imported pandas and numpy and read the data
import pandas as pd
import numpy as np
df=pd.read_excel(r"C:\Users\HP\Downloads\Final Projects Machine Learning\Final Projects Machine Learning\Project 1.0\E-commerce.xlsx")
df
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
#Print the column names present in our data
print(df.columns)
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
#Perform our column names in a list
list_column=list(df.columns)
print(list_column)
# Out:
# ['1Gender of respondent', '2 How old are you? ', '3 Which city do you shop online from?', '4 What is the Pin Code of where you shop online from?', '5 Since How Long You are Shopping Online ?', '6 How many times you have made an online purchase in the past 1 year?', '7 How do you access the internet while shopping on-line?', '8 Which device do you use to access the online shopping?', '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ', '10 What is the operating system (OS) of your device?\t\t\t\t                                          ', '11 What browser do you run on your device to access the website?\t\t\t                                                          ', '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ', '13 After first visit, how do you reach the online retail store?\t\t\t\t                                    
# ...

# %%
#How many columns names are present//count
len(df.columns)
# Out:
# 71

# %%
#USING isnull() function// count of how many nan values are present in each columns
df.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
#Total count of values overall
df.isnull().sum().sum()
# Out:
# 0

# %%
#Print first 5 rows in data
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
#Print last 5 rows in data
df.tail()
# Out:
#     1Gender of respondent 2 How old are you?   \
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 264                                 Solan
# 265                             Ghaziabad
# 266                            Bangalore
# 267                                 Solan
# 268                             Ghaziabad
#
#      4 What is the Pin Code of where you shop online from?  \
# 264                                             173212
# 265                                             201008
# 266                                             560010
# 267                                             173229
# 268                                             201009
#
#     5 Since How Long You are Shopping Online ?  \
# ...

# %%
#Print random 4 rows in data
df.sample(n=4)
# Out:
#     1Gender of respondent 2 How old are you?   \
# 211                Female         21-30 years
# 5                  Female         31-40 years
# 90                 Female         31-40 years
# 134                  Male         31-40 years
#
#     3 Which city do you shop online from?  \
# 211                            Bangalore
# 5                                   Noida
# 90                                  Delhi
# 134                                 Delhi
#
#      4 What is the Pin Code of where you shop online from?  \
# 211                                             560002
# 5                                               201308
# 90                                              110014
# 134                                             110009
#
#     5 Since How Long You are Shopping Online ?  \
# 211                              Above 4 years
# 5                                Above 4 years
# 90                            Less than 1 year
# ...

# %%
#checking shapes (rows and columns)
df.shape
# Out:
# (269, 71)

# %%
#Print first 5 rows for selected 3 columns (2 How old are you? ,3 Which city do you shop online from?,5 Since How Long You are Shopping Online ?,Perceived Trustworthiness)
df[['2 How old are you? ','3 Which city do you shop online from?','5 Since How Long You are Shopping Online ?','Perceived Trustworthiness']].head()
# Out:
#   2 How old are you?  3 Which city do you shop online from?  \
# 0         31-40 years                                 Delhi
# 1         21-30 years                                 Delhi
# 2         21-30 years                         Greater Noida
# 3         21-30 years                               Karnal
# 4         21-30 years                            Bangalore
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# 1                              Above 4 years
# 2                                  3-4 years
# 3                                  3-4 years
# 4                                  2-3 years
#
#                Perceived Trustworthiness
# 0                           Flipkart.com
# 1                             Myntra.com
# 2                  Amazon.in, Myntra.com
# 3  Amazon.in, Flipkart.com, Snapdeal.com
# 4                  Amazon.in, Myntra.com

# %%
#Delete '1Gender of respondent' column from data
del df['1Gender of respondent']
print(df)
# Out:
#     2 How old are you?  3 Which city do you shop online from?  \
# 0           31-40 years                                 Delhi
# 1           21-30 years                                 Delhi
# 2           21-30 years                         Greater Noida
# 3           21-30 years                               Karnal
# 4           21-30 years                            Bangalore
# ..                  ...                                   ...
# 264         21-30 years                                 Solan
# 265         31-40 years                             Ghaziabad
# 266         41-50 yaers                            Bangalore
# 267  Less than 20 years                                 Solan
# 268         41-50 yaers                             Ghaziabad
#
#      4 What is the Pin Code of where you shop online from?  \
# 0                                               110009
# 1                                               110030
# ...

# %%
#Craete a new Column full of missing values
df['final_column']=np.nan
df
# Out:
#     2 How old are you?  3 Which city do you shop online from?  \
# 0           31-40 years                                 Delhi
# 1           21-30 years                                 Delhi
# 2           21-30 years                         Greater Noida
# 3           21-30 years                               Karnal
# 4           21-30 years                            Bangalore
# ..                  ...                                   ...
# 264         21-30 years                                 Solan
# 265         31-40 years                             Ghaziabad
# 266         41-50 yaers                            Bangalore
# 267  Less than 20 years                                 Solan
# 268         41-50 yaers                             Ghaziabad
#
#      4 What is the Pin Code of where you shop online from?  \
# 0                                               110009
# 1                                               110030
# ...

# %%
#Drop Column if they only contain Missing Values
df.dropna(axis=1,how='all')
# Out:
#     2 How old are you?  3 Which city do you shop online from?  \
# 0           31-40 years                                 Delhi
# 1           21-30 years                                 Delhi
# 2           21-30 years                         Greater Noida
# 3           21-30 years                               Karnal
# 4           21-30 years                            Bangalore
# ..                  ...                                   ...
# 264         21-30 years                                 Solan
# 265         31-40 years                             Ghaziabad
# 266         41-50 yaers                            Bangalore
# 267  Less than 20 years                                 Solan
# 268         41-50 yaers                             Ghaziabad
#
#      4 What is the Pin Code of where you shop online from?  \
# 0                                               110009
# 1                                               110030
# ...

# %%
#All nan values is filled with 0
df.fillna(0)
# Out:
#     2 How old are you?  3 Which city do you shop online from?  \
# 0           31-40 years                                 Delhi
# 1           21-30 years                                 Delhi
# 2           21-30 years                         Greater Noida
# 3           21-30 years                               Karnal
# 4           21-30 years                            Bangalore
# ..                  ...                                   ...
# 264         21-30 years                                 Solan
# 265         31-40 years                             Ghaziabad
# 266         41-50 yaers                            Bangalore
# 267  Less than 20 years                                 Solan
# 268         41-50 yaers                             Ghaziabad
#
#      4 What is the Pin Code of where you shop online from?  \
# 0                                               110009
# 1                                               110030
# ...

# %%
#All nan values is filled with value of 5
fill_df=df.fillna(value=5)
fill_df
# Out:
#     2 How old are you?  3 Which city do you shop online from?  \
# 0           31-40 years                                 Delhi
# 1           21-30 years                                 Delhi
# 2           21-30 years                         Greater Noida
# 3           21-30 years                               Karnal
# 4           21-30 years                            Bangalore
# ..                  ...                                   ...
# 264         21-30 years                                 Solan
# 265         31-40 years                             Ghaziabad
# 266         41-50 yaers                            Bangalore
# 267  Less than 20 years                                 Solan
# 268         41-50 yaers                             Ghaziabad
#
#      4 What is the Pin Code of where you shop online from?  \
# 0                                               110009
# 1                                               110030
# ...

# %%
#Set hierarchical indexing
df.set_index(['2 How old are you? ','3 Which city do you shop online from?','4 What is the Pin Code of where you shop online from?',
              '5 Since How Long You are Shopping Online ?',],drop=False)
# Out:
#                                                                                                                                                         2 How old are you?   \
# 2 How old are you?  3 Which city do you shop online from? 4 What is the Pin Code of where you shop online... 5 Since How Long You are Shopping Online ?
# 31-40 years         Delhi                                 110009                                             Above 4 years                                      31-40 years
# 21-30 years         Delhi                                 110030                                             Above 4 years                                      21-30 years
#                     Greater Noida                         201308                                             3-4 years                                          21-30 years
# ...

# %%
#Set hierarchical indexing, drop=True and save it for future
df.set_index(['2 How old are you? ','3 Which city do you shop online from?'],drop=True,inplace=True)

# %%
df
# Out:
#                                                            4 What is the Pin Code of where you shop online from?  \
# 2 How old are you?  3 Which city do you shop online from?
# 31-40 years         Delhi                                                                             110009
# 21-30 years         Delhi                                                                             110030
#                     Greater Noida                                                                     201308
#                     Karnal                                                                            132001
#                     Bangalore                                                                         530068
# ...                                                                                                      ...
#                     Solan                                                                             173212
# ...

# %%
#DataFrame Manipulation
#Lets Import imp libraries
import numpy as np
import pandas as pd

# %%
df_new=pd.read_excel(r"C:\Users\HP\Downloads\Final Projects Machine Learning\Final Projects Machine Learning\Project 1.0\E-commerce.xlsx")
df_new
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
#Imports the warnings module and ignore all filter warnings//manipulate the data using two columns 
import warnings
warnings.filterwarnings('ignore')
manipulated=df_new[['2 How old are you? ','3 Which city do you shop online from?']]
manipulated
# Out:
#     2 How old are you?  3 Which city do you shop online from?
# 0           31-40 years                                 Delhi
# 1           21-30 years                                 Delhi
# 2           21-30 years                         Greater Noida
# 3           21-30 years                               Karnal
# 4           21-30 years                            Bangalore
# ..                  ...                                   ...
# 264         21-30 years                                 Solan
# 265         31-40 years                             Ghaziabad
# 266         41-50 yaers                            Bangalore
# 267  Less than 20 years                                 Solan
# 268         41-50 yaers                             Ghaziabad
#
# [269 rows x 2 columns]

# %%
#Add one column full of nan values
df_new['final_column']=np.nan
df_new
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
#Assign value=5 for nan column
df_new_fill=df_new.fillna(value=5)
df_new_fill
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
#Print the details of last column added
print(df_new_fill.final_column)
# Out:
# 0      5.0
# 1      5.0
# 2      5.0
# 3      5.0
# 4      5.0
#       ...
# 264    5.0
# 265    5.0
# 266    5.0
# 267    5.0
# 268    5.0
# Name: final_column, Length: 269, dtype: float64

# %%
#Print the details and its location of 0th row in data
df_new_fill.iloc[0]
# Out:
# 1Gender of respondent                                                            Male
# 2 How old are you?                                                        31-40 years
# 3 Which city do you shop online from?                                           Delhi
# 4 What is the Pin Code of where you shop online from?                          110009
# 5 Since How Long You are Shopping Online ?                              Above 4 years
#                                                                             ...
# Change in website/Application design                                     Flipkart.com
# Frequent disruption when moving from one page to another                    Amazon.in
# Website is as efficient as before                                           Amazon.in
# Which of the Indian online retailer would you recommend to a friend?     Flipkart.com
# final_column                                                                      5.0
# Name: 0, Length: 72, dtype: object

# %%
#Print all the details of '1Gender of respondent'=='Female'
print(df_new_fill[df_new_fill['1Gender of respondent']=='Female'])
# Out:
#     1Gender of respondent 2 How old are you?   \
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 4                  Female         21-30 years
# 5                  Female         31-40 years
# 8                  Female  Less than 20 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 1                                   Delhi
# 2                           Greater Noida
# 4                              Bangalore
# 5                                   Noida
# 8                                   Solan
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
#Select Rows with '1Gender of respondent'=='Female' and '3 Which city do you shop online from?'=='Delhi'
condition1=df_new_fill['1Gender of respondent']=='Female'
condition2=df_new_fill['3 Which city do you shop online from?']=='Delhi'
print(df_new_fill[(condition1)&(condition2)])
# Out:
#     1Gender of respondent 2 How old are you?   \
# 1                  Female         21-30 years
# 9                  Female         31-40 years
# 18                 Female         41-50 yaers
# 90                 Female         31-40 years
# 93                 Female         21-30 years
# 98                 Female         31-40 years
# 114                Female         21-30 years
# 119                Female         31-40 years
# 144                Female         31-40 years
# 145                Female         21-30 years
# 160                Female         31-40 years
# 163                Female         31-40 years
# 169                Female         21-30 years
# 222                Female         21-30 years
# 235                Female         31-40 years
# 238                Female         31-40 years
# 257                Female         31-40 years
# 258                Female         21-30 years
#
#     3 Which city do you shop online from?  \
# ...

# %%
#Print only '7 How do you access the internet while shopping on-line?','8 Which device do you use to access the online shopping?' of condition 1
print(df_new_fill[condition1][['7 How do you access the internet while shopping on-line?','8 Which device do you use to access the online shopping?']])
# Out:
#     7 How do you access the internet while shopping on-line?  \
# 1                                                Wi-Fi
# 2                                      Mobile Internet
# 4                                                Wi-Fi
# 5                                                Wi-Fi
# 8                                                Wi-Fi
# ..                                                 ...
# 264                                    Mobile Internet
# 265                                    Mobile Internet
# 266                                    Mobile internet
# 267                                              Wi-Fi
# 268                                    Mobile Internet
#
#     8 Which device do you use to access the online shopping?
# 1                                           Smartphone
# 2                                           Smartphone
# 4                                           Smartphone
# 5                                           Smartphone
# ...

# %%
#The above data is shown as dataframe
selected=df_new_fill[condition1][['7 How do you access the internet while shopping on-line?','8 Which device do you use to access the online shopping?']]
selected
# Out:
#     7 How do you access the internet while shopping on-line?  \
# 1                                                Wi-Fi
# 2                                      Mobile Internet
# 4                                                Wi-Fi
# 5                                                Wi-Fi
# 8                                                Wi-Fi
# ..                                                 ...
# 264                                    Mobile Internet
# 265                                    Mobile Internet
# 266                                    Mobile internet
# 267                                              Wi-Fi
# 268                                    Mobile Internet
#
#     8 Which device do you use to access the online shopping?
# 1                                           Smartphone
# 2                                           Smartphone
# 4                                           Smartphone
# 5                                           Smartphone
# ...

# %%
#Applying groupby function//Group and display the details of '1Gender of respondent'// if numerals in it, will print sum in number
grouped=df_new_fill.groupby('1Gender of respondent')
print(grouped.sum())
# Out:
#                                                      2 How old are you?   \
# 1Gender of respondent
# Female                 21-30 years21-30 years21-30 years31-40 yearsLe...
# Male                   31-40 years21-30 years41-50 yaers41-50 yaers31...
#
#                                    3 Which city do you shop online from?  \
# 1Gender of respondent
# Female                 DelhiGreater NoidaBangalore NoidaSolanDelhiNoi...
# Male                   DelhiKarnal DelhiDelhiMoradabadNoidaDelhiGurga...
#
#                        4 What is the Pin Code of where you shop online from?  \
# 1Gender of respondent
# Female                                                          44513302
# Male                                                            14791984
#
#                               5 Since How Long You are Shopping Online ?  \
# 1Gender of respondent
# Female                 Above 4 years3-4 years2-3 yearsAbove 4 years2-...
# ...
